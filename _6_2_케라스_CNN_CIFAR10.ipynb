# %% [markdown]
# <a href="https://colab.research.google.com/github/KimJisanER/KimJisan_TS/blob/main/_6_2_%EC%BC%80%EB%9D%BC%EC%8A%A4_CNN_CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 케라스 CNN CIFAR 10
#
# - 50,000개의 학습데이터, 10,000개의 테스트 데이터로 구성
#
# - 데이터 복잡도가 MNIST보다 훨씬 높은 특징이 있음
#   - 신경망이 특징을 검출하기 어려움
#
#   <img src="https://www.researchgate.net/profile/Jean_Elsner/publication/329969195/figure/fig1/AS:708799606317059@1546002403551/Images-from-the-CIFAR-10-13-dataset-and-their-corresponding-classes-CIFAR-10.ppm">

# %% [markdown]
# ### modules import

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

import numpy as np

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

print(x_train_full.shape, y_train_full.shape)
print(x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
print(y_test[5])
# Out:
# [6]

# %%
np.random.seed(777)

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'sheep' ,'truck']

sample_size=9
random_idx = np.random.randint(60000, size=sample_size)

plt.figure(figsize=(5,5))
for i,idx in enumerate(random_idx):
  plt.subplot(3, 3, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(x_train_full[i])
  plt.xlabel(class_names[int(y_train_full[i])])

plt.show()

# %%
x_mean = np.mean(x_train_full, axis=(0, 1, 2))
x_std = np.std(x_train_full, axis=(0, 1, 2))

x_train_full = (x_train_full - x_mean) / x_std
x_test = (x_test - x_mean) / x_std

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size=0.3)

# %%
print(x_train.shape)
print(y_train.shape)

print(x_val.shape)
print(y_val.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (35000, 32, 32, 3)
# (35000, 1)
# (15000, 32, 32, 3)
# (15000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# ### 모델 구성 및 컴파일

# %%
def model_build():
  model = Sequential()

  input = Input(shape=(32, 32, 3))

  output = Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(input)
  output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)

  output = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(output)
  output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)

  output = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(output)
  output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)

  output = Flatten()(output)
  output = Dense(256, activation='relu')(output)
  output = Dense(128, activation='relu')(output)
  output = Dense(10, activation='softmax')(output)

  model = Model(inputs=[input], outputs=output)

  model.compile(optimizer=Adam(learning_rate=1e-4),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
model = model_build()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 651,978
# Trainable params: 651,978
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습 및 평가
# - [런타임]에서 GPU 설정

# %%
history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=256,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 137/137 [==============================] - 12s 14ms/step - loss: 1.8844 - accuracy: 0.3309 - val_loss: 1.6072 - val_accuracy: 0.4356
# Epoch 2/30
# 137/137 [==============================] - 1s 11ms/step - loss: 1.5277 - accuracy: 0.4596 - val_loss: 1.4655 - val_accuracy: 0.4764
# Epoch 3/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.3957 - accuracy: 0.5072 - val_loss: 1.3602 - val_accuracy: 0.5189
# Epoch 4/30
# 137/137 [==============================] - 1s 11ms/step - loss: 1.3108 - accuracy: 0.5384 - val_loss: 1.2924 - val_accuracy: 0.5395
# Epoch 5/30
# 137/137 [==============================] - 1s 11ms/step - loss: 1.2509 - accuracy: 0.5578 - val_loss: 1.2424 - val_accuracy: 0.5575
# Epoch 6/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.1969 - accuracy: 0.5809 - val_loss: 1.1966 - val_accuracy: 0.5772
# Epoch 7/30
# 137/137 [==============================] - 1s 11ms/step - loss: 1.1517 - accuracy: 0.5963 - val_loss: 1.1796 - val_accuracy: 0.5835
# Epoch 8/30
# 137/137 [==============================] - 1s 11ms/step - loss: 1.1100 - accuracy: 0.6131 - val_loss: 1.1425 - val_accuracy: 0.5957
# Epoch 9/30
# 137/137 [==============================] - 1s 11ms/step - loss: 1.0668 - accuracy: 0.6276 - val_loss: 1.1188 - val_accuracy: 0.6061
# Epoch 10/30
# 137/137 [==============================] - 1s 11ms/step - loss: 1.0397 - accuracy: 0.6387 - val_loss: 1.0866 - val_accuracy: 0.6214
# Epoch 11/30
# 137/137 [==============================] - 1s 11ms/step - loss: 1.0139 - accuracy: 0.6493 - val_loss: 1.0863 - val_accuracy: 0.6164
# Epoch 12/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9790 - accuracy: 0.6598 - val_loss: 1.0424 - val_accuracy: 0.6349
# Epoch 13/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.9527 - accuracy: 0.6679 - val_loss: 1.0446 - val_accuracy: 0.6341
# Epoch 14/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9363 - accuracy: 0.6769 - val_loss: 1.0347 - val_accuracy: 0.6357
# Epoch 15/30
# 137/137 [==============================] - 1s 10ms/step - loss: 0.9068 - accuracy: 0.6875 - val_loss: 1.0216 - val_accuracy: 0.6471
# Epoch 16/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.8877 - accuracy: 0.6922 - val_loss: 0.9908 - val_accuracy: 0.6525
# Epoch 17/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.8665 - accuracy: 0.7010 - val_loss: 0.9857 - val_accuracy: 0.6570
# Epoch 18/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8476 - accuracy: 0.7061 - val_loss: 0.9691 - val_accuracy: 0.6636
# Epoch 19/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.8205 - accuracy: 0.7173 - val_loss: 0.9727 - val_accuracy: 0.6603
# Epoch 20/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.8096 - accuracy: 0.7190 - val_loss: 0.9439 - val_accuracy: 0.6707
# Epoch 21/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.7944 - accuracy: 0.7257 - val_loss: 0.9761 - val_accuracy: 0.6581
# Epoch 22/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.7713 - accuracy: 0.7347 - val_loss: 0.9252 - val_accuracy: 0.6762
# Epoch 23/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.7557 - accuracy: 0.7421 - val_loss: 0.9263 - val_accuracy: 0.6755
# Epoch 24/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.7396 - accuracy: 0.7454 - val_loss: 0.9232 - val_accuracy: 0.6815
# Epoch 25/30
# 137/137 [==============================] - 1s 10ms/step - loss: 0.7200 - accuracy: 0.7551 - val_loss: 0.9801 - val_accuracy: 0.6673
# Epoch 26/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.7081 - accuracy: 0.7578 - val_loss: 0.9256 - val_accuracy: 0.6783
# Epoch 27/30
# 137/137 [==============================] - 1s 10ms/step - loss: 0.6889 - accuracy: 0.7641 - val_loss: 0.9093 - val_accuracy: 0.6819
# Epoch 28/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.6816 - accuracy: 0.7656 - val_loss: 0.9093 - val_accuracy: 0.6821
# Epoch 29/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.6707 - accuracy: 0.7688 - val_loss: 0.9076 - val_accuracy: 0.6853
# Epoch 30/30
# 137/137 [==============================] - 1s 11ms/step - loss: 0.6530 - accuracy: 0.7769 - val_loss: 0.9057 - val_accuracy: 0.6901

# %% [markdown]
# ### 학습 과정 시각화

# %%
plt.figure(figsize=(12,4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['val_loss'], 'r:', label='val loss')
plt.xlabel(['Epochs'])
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'b--', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r:', label='val accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# - 해당 모델은 성능이 좋지 않음
# - 규제화, 드롭아웃 등 과대적합을 방지하는 기술 필요

# %%
def model_build2():
  model = Sequential()

  input = Input(shape=(32, 32, 3))

  output = Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(input)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)

  output = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)

  output = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)
  output = Dropout(0.5)(output)

  output = Flatten()(output)
  output = Dense(256, activation='relu')(output)
  output = Dropout(0.5)(output)
  output = Dense(128, activation='relu')(output)
  output = Dense(10, activation='softmax')(output)

  model = Model(inputs=[input], outputs=output)

  model.compile(optimizer=Adam(learning_rate=1e-4),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
model = model_build2()
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_2 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 128)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 256)               524544
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 652,874
# Trainable params: 652,426
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습 및 평가
# - [런타임]에서 GPU 설정

# %%
history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=256,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 137/137 [==============================] - 3s 16ms/step - loss: 2.6305 - accuracy: 0.1995 - val_loss: 2.2260 - val_accuracy: 0.2098
# Epoch 2/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.9756 - accuracy: 0.2909 - val_loss: 1.9524 - val_accuracy: 0.3018
# Epoch 3/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.8322 - accuracy: 0.3311 - val_loss: 1.6243 - val_accuracy: 0.4275
# Epoch 4/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.7184 - accuracy: 0.3715 - val_loss: 1.5218 - val_accuracy: 0.4675
# Epoch 5/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.6464 - accuracy: 0.3991 - val_loss: 1.4595 - val_accuracy: 0.4925
# Epoch 6/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.5699 - accuracy: 0.4270 - val_loss: 1.4018 - val_accuracy: 0.5116
# Epoch 7/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.5209 - accuracy: 0.4469 - val_loss: 1.3513 - val_accuracy: 0.5297
# Epoch 8/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.4758 - accuracy: 0.4654 - val_loss: 1.3104 - val_accuracy: 0.5454
# Epoch 9/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.4315 - accuracy: 0.4839 - val_loss: 1.2785 - val_accuracy: 0.5586
# Epoch 10/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.4029 - accuracy: 0.4954 - val_loss: 1.2514 - val_accuracy: 0.5732
# Epoch 11/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.3619 - accuracy: 0.5078 - val_loss: 1.2180 - val_accuracy: 0.5864
# Epoch 12/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.3233 - accuracy: 0.5213 - val_loss: 1.1810 - val_accuracy: 0.5969
# Epoch 13/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.2922 - accuracy: 0.5341 - val_loss: 1.1641 - val_accuracy: 0.6043
# Epoch 14/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.2646 - accuracy: 0.5463 - val_loss: 1.1286 - val_accuracy: 0.6155
# Epoch 15/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.2342 - accuracy: 0.5574 - val_loss: 1.1018 - val_accuracy: 0.6228
# Epoch 16/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.2087 - accuracy: 0.5687 - val_loss: 1.0829 - val_accuracy: 0.6307
# Epoch 17/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.1768 - accuracy: 0.5808 - val_loss: 1.0644 - val_accuracy: 0.6351
# Epoch 18/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.1574 - accuracy: 0.5865 - val_loss: 1.0437 - val_accuracy: 0.6439
# Epoch 19/30
# 137/137 [==============================] - 2s 15ms/step - loss: 1.1421 - accuracy: 0.5922 - val_loss: 1.0269 - val_accuracy: 0.6475
# Epoch 20/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.1141 - accuracy: 0.6013 - val_loss: 0.9984 - val_accuracy: 0.6551
# Epoch 21/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.0970 - accuracy: 0.6070 - val_loss: 0.9947 - val_accuracy: 0.6587
# Epoch 22/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.0717 - accuracy: 0.6165 - val_loss: 0.9770 - val_accuracy: 0.6655
# Epoch 23/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.0581 - accuracy: 0.6229 - val_loss: 0.9672 - val_accuracy: 0.6699
# Epoch 24/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.0431 - accuracy: 0.6275 - val_loss: 0.9479 - val_accuracy: 0.6718
# Epoch 25/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.0196 - accuracy: 0.6358 - val_loss: 0.9401 - val_accuracy: 0.6774
# Epoch 26/30
# 137/137 [==============================] - 2s 12ms/step - loss: 1.0171 - accuracy: 0.6407 - val_loss: 0.9314 - val_accuracy: 0.6825
# Epoch 27/30
# 137/137 [==============================] - 2s 13ms/step - loss: 0.9953 - accuracy: 0.6469 - val_loss: 0.9176 - val_accuracy: 0.6837
# Epoch 28/30
# 137/137 [==============================] - 2s 12ms/step - loss: 0.9794 - accuracy: 0.6533 - val_loss: 0.9042 - val_accuracy: 0.6869
# Epoch 29/30
# 137/137 [==============================] - 2s 12ms/step - loss: 0.9641 - accuracy: 0.6590 - val_loss: 0.9097 - val_accuracy: 0.6846
# Epoch 30/30
# 137/137 [==============================] - 2s 13ms/step - loss: 0.9506 - accuracy: 0.6628 - val_loss: 0.8861 - val_accuracy: 0.6931

# %% [markdown]
# ### 학습 과정 시각화

# %%
plt.figure(figsize=(12,4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['val_loss'], 'r:', label='val loss')
plt.xlabel(['Epochs'])
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'b--', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r:', label='val accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.show()
