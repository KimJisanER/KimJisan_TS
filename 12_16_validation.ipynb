# %% [markdown]
# <a href="https://colab.research.google.com/github/KimJisanER/KimJisan_TS/blob/main/12_16_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 라이브러리 불러오기
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Mnist 데이터셋
mnist = tf.keras.datasets.mnist
(X, y), (x_test, y_test) = mnist.load_data()

# 시퀀셜 모델 만들기
model = Sequential([
                    Flatten(input_shape=(28,28)),
                    Dense(64, activation='relu'),
                    Dense(10, activation='softmax')
])

# 모델 컴파일

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
#validation_split 활용
history = model.fit(X,y, validation_split=0.2, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 750/750 [==============================] - 5s 6ms/step - loss: 4.0767 - accuracy: 0.7554 - val_loss: 0.7739 - val_accuracy: 0.8292
# Epoch 2/5
# 750/750 [==============================] - 3s 5ms/step - loss: 0.6564 - accuracy: 0.8463 - val_loss: 0.5574 - val_accuracy: 0.8836
# Epoch 3/5
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4673 - accuracy: 0.8874 - val_loss: 0.4405 - val_accuracy: 0.9026
# Epoch 4/5
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3648 - accuracy: 0.9081 - val_loss: 0.3775 - val_accuracy: 0.9102
# Epoch 5/5
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3111 - accuracy: 0.9204 - val_loss: 0.3403 - val_accuracy: 0.9228

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['training','validation'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['training','validation'])

# %% [markdown]
# 2.train_test_split 활용

# %%
#train_test_split
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
# 시퀀셜 모델 만들기
model = Sequential([
                    Flatten(input_shape=(28,28)),
                    Dense(64, activation='relu'),
                    Dense(10, activation='softmax')
])

# 모델 컴파일

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

#훈련(학습) validation_data
history=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 750/750 [==============================] - 4s 5ms/step - loss: 3.7825 - accuracy: 0.7663 - val_loss: 0.8505 - val_accuracy: 0.8074
# Epoch 2/5
# 750/750 [==============================] - 3s 5ms/step - loss: 0.6367 - accuracy: 0.8533 - val_loss: 0.5785 - val_accuracy: 0.8704
# Epoch 3/5
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4562 - accuracy: 0.8898 - val_loss: 0.4677 - val_accuracy: 0.8965
# Epoch 4/5
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3597 - accuracy: 0.9097 - val_loss: 0.3868 - val_accuracy: 0.9047
# Epoch 5/5
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2848 - accuracy: 0.9249 - val_loss: 0.3282 - val_accuracy: 0.9241

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['training','validation'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['training','validation'])
